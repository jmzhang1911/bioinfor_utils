# %%
library(tidyverse)

# %%
 KEGG <- read.csv('./new_KEGG.info', header=F, sep = '\t') %>% distinct()

# %%
KEGG
# Out:
#       V1      V2                           V3       V4
# 1     ko00010 Glycolysis / Gluconeogenesis Dlat     ENSMUSG00000000168
# 2     ko00010 Glycolysis / Gluconeogenesis Hk2      ENSMUSG00000000628
# 3     ko00010 Glycolysis / Gluconeogenesis Eno2     ENSMUSG00000004267
# 4     ko00010 Glycolysis / Gluconeogenesis G6pc2    ENSMUSG00000005232
# 5     ko00010 Glycolysis / Gluconeogenesis Aldh3a2  ENSMUSG00000010025
# 6     ko00010 Glycolysis / Gluconeogenesis Pgam1    ENSMUSG00000011752
# 7     ko00010 Glycolysis / Gluconeogenesis Aldh1a3  ENSMUSG00000015134
# 8     ko00010 Glycolysis / Gluconeogenesis Aldoc    ENSMUSG00000017390
# 9     ko00010 Glycolysis / Gluconeogenesis Aldh3a1  ENSMUSG00000019102
# 10    ko00010 Glycolysis / Gluconeogenesis Hkdc1    ENSMUSG00000020080
# 11    ko00010 Glycolysis / Gluconeogenesis Pfkl     ENSMUSG00000020277
# 12    ko00010 Glycolysis / Gluconeogenesis Pgam2    ENSMUSG00000020475
# ...
